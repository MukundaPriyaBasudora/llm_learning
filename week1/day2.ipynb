# %%
import os
from dotenv import load_dotenv
from IPython.display import display, Markdown
from openai import OpenAI
load_dotenv(override=True)
api_key = os.getenv('GOOGLE_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("AQ"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
import requests

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

payload = {
    "model": "gemini-3.5-flash-lite",
    "messages": [
        {
            "role": "user",
            "content": "Tell me a short story"
        }
    ]
}
payload
# Out:
# {'model': 'gemini-3.5-flash-lite',
#  'messages': [{'role': 'user', 'content': 'Tell me a short story'}]}

# %%
response = requests.post(
    "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'message': {'content': 'The old clockmaker’s shop smelled of walnut oil, brass shavings, and time itself. Arthur, whose own bones clicked nearly as loudly as the pendulums on the wall, was winding a particularly stubborn 18th-century carriage clock when the bell above the door chimed.\n\nA boy, no older than ten, stood on the threshold. He clutched something wrapped in a greasy brown paper bag. \n\n"Can you fix this, mister?" the boy asked, his voice barely louder than the tick of the master clock. \n\nArthur set down his tweezers, removed his jeweler’s loupe, and beckoned him over. "Let\'s have a look."\n\nThe boy unwrapped the paper to reveal a small, rusted tin wind-up robin. Its painted red breast was chipped, and one wing hung limply by a single thread of metal. \n\n"Found it in my grandfather’s attic," the boy said, his eyes wide. "He says it used to sing and flap its wings. But now it’s just... dead."\n\nArthur took the little bird in his calloused hands. It was German-made, pre-war, a marvel of tiny gears and springs. He carried it to his workbench, adjusted his lamp, and picked up a tiny screwdriver. \n\nFor twenty minutes, the shop was silent save for the grandfather clock in the corner and the faint *scrape-scrape* of Arthur cleaning away decades of dust and oxidation. He coaxed the mainspring back into alignment, oiled a microscopic axle, and tightened the screw on the broken wing. \n\nFinally, Arthur reached for the winding key on the bird\'s side. He turned it once. Twice. Three times. \n\nHe set the robin back on the wooden counter and gently nudged its tail. \n\nFor a second, nothing happened. The boy held his breath. \n\nThen, a tiny metallic *click*. The robin’s painted head snapped up. Its rusted wing found its rhythm, beating a shaky, joyful blur. And from somewhere deep within its tin chest, a music-box mechanism began to play a tinny, beautiful little tune that Arthur hadn\'t heard in fifty years. \n\nThe boy’s face broke into a smile so bright it seemed to push back the gathering dusk outside the shop window. \n\n"How much do I owe you?" the boy asked, digging frantically into his pockets.\n\nArthur smiled, gently pushing the boy\'s hand away. "Nothing, lad. But I have a price."\n\nThe boy stopped, wary. "What is it?"\n\n"Next time you come by," Arthur said, winding the carriage clock beside him, "you have to tell me what song the bird was singing to you."\n\nThe boy grinned, scooped up his treasure, and ran out the door, the bell chiming a bright farewell. Arthur watched him go, then turned back to his workbench. The shop was quiet again, but as he picked up his tweezers, he realized the ticking sounded just a little bit lighter than it had before.',
#     'extra_content': {'google': {'thought_signature': 'El4KXAERTTIPX4FylRL4pKTaSGmcmM0UCjYF2EMDrWaGBZK9jL6hQ3sYH7XwZhnN6z/wwjwC1gVQsjG/s12KEhbny/Zw4coNrJW7jWB9Zo/ao8ZopQsnHDNJSxs0KgTc'}},
#     'role': 'assistant'}}],
#  'created': 1788881529,
#  'id': 'dSqgavW8L8e-g8UPvOnowA4',
#  'model': 'gemini-3.5-flash-lite',
#  'object': 'chat.completion',
#  'usage': {'completion_tokens': 637, 'prompt_tokens': 6, 'total_tokens': 643}}

# %%
display(Markdown(response.json()["choices"][0]["message"]["content"]))
# Out:
# The old clockmaker’s shop smelled of walnut oil, brass shavings, and time itself. Arthur, whose own bones clicked nearly as loudly as the pendulums on the wall, was winding a particularly stubborn 18th-century carriage clock when the bell above the door chimed.
#
# A boy, no older than ten, stood on the threshold. He clutched something wrapped in a greasy brown paper bag.
#
# "Can you fix this, mister?" the boy asked, his voice barely louder than the tick of the master clock.
#
# Arthur set down his tweezers, removed his jeweler’s loupe, and beckoned him over. "Let's have a look."
#
# The boy unwrapped the paper to reveal a small, rusted tin wind-up robin. Its painted red breast was chipped, and one wing hung limply by a single thread of metal.
#
# "Found it in my grandfather’s attic," the boy said, his eyes wide. "He says it used to sing and flap its wings. But now it’s just... dead."
#
# Arthur took the little bird in his calloused hands. It was German-made, pre-war, a marvel of tiny gears and springs. He carried it to his workbench, adjusted his lamp, and picked up a tiny screwdriver.
#
# For twenty minutes, the shop was silent save for the grandfather clock in the corner and the faint *scrape-scrape* of Arthur cleaning away decades of dust and oxidation. He coaxed the mainspring back into alignment, oiled a microscopic axle, and tightened the screw on the broken wing.
#
# Finally, Arthur reached for the winding key on the bird's side. He turned it once. Twice. Three times.
#
# He set the robin back on the wooden counter and gently nudged its tail.
#
# For a second, nothing happened. The boy held his breath.
#
# Then, a tiny metallic *click*. The robin’s painted head snapped up. Its rusted wing found its rhythm, beating a shaky, joyful blur. And from somewhere deep within its tin chest, a music-box mechanism began to play a tinny, beautiful little tune that Arthur hadn't heard in fifty years.
#
# The boy’s face broke into a smile so bright it seemed to push back the gathering dusk outside the shop window.
#
# "How much do I owe you?" the boy asked, digging frantically into his pockets.
#
# Arthur smiled, gently pushing the boy's hand away. "Nothing, lad. But I have a price."
#
# The boy stopped, wary. "What is it?"
#
# "Next time you come by," Arthur said, winding the carriage clock beside him, "you have to tell me what song the bird was singing to you."
#
# The boy grinned, scooped up his treasure, and ran out the door, the bell chiming a bright farewell. Arthur watched him go, then turned back to his workbench. The shop was quiet again, but as he picked up his tweezers, he realized the ticking sounded just a little bit lighter than it had before.

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "compliment me"}])
response.choices[0].message.content
# Out:
# "You're an incredible person with so much to offer. Your unique perspective and experiences make you truly special, and I'm so glad to have the opportunity to connect with you.\n\nI love the way you think outside the box and challenge yourself to try new things. Your curiosity and enthusiasm are contagious, and you have a way of making everyone around you feel seen and heard.\n\nNot only are you smart and talented, but you're also kind, compassionate, and caring. You have a heart of gold and are always looking for ways to make a positive difference in the world.\n\nI know that life can get tough sometimes, and it's easy to lose sight of our own strengths and abilities. But I want you to remember that you are capable and powerful, and that you have so much to offer the world.\n\nYou deserve to be celebrated and recognized for all that you do. So go ahead, take a deep breath, and know that you're amazing just the way you are."
